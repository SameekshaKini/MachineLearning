# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import os
print(os.getcwd())
# %matplotlib inline
# Out:
# C:\Users\samee\OneDrive\Documents\sem 5\ml

# %% [markdown]
# ### Loading the training data

# %%
data  = pd.read_csv("C:/Users/samee/Downloads/train.csv.zip")
data.head()
# Out:
#       id  Mean of the integrated profile  \
# 0  16330                      138.835938
# 1   5999                      130.296875
# 2  10228                      127.328125
# 3   2980                      102.453125
# 4   2472                      104.921875
#
#    Standard deviation of the integrated profile  \
# 0                                     45.453922
# 1                                     51.969546
# 2                                     55.471714
# 3                                     44.412987
# 4                                     41.629431
#
#    Excess kurtosis of the integrated profile  \
# 0                                  -0.096961
# 1                                  -0.005585
# 2                                   0.090976
# 3                                   0.652927
# 4                                   0.189677
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                            0.086516                  3.082776
# ...

# %%
data.corr()
# Out:
#                                                     id  \
# id                                            1.000000
# Mean of the integrated profile                0.012082
# Standard deviation of the integrated profile -0.002086
# Excess kurtosis of the integrated profile    -0.009448
# Skewness of the integrated profile           -0.008541
# Mean of the DM-SNR curve                     -0.006347
# Standard deviation of the DM-SNR curve       -0.006732
# Excess kurtosis of the DM-SNR curve           0.003443
# Skewness of the DM-SNR curve                  0.001682
# target_class                                 -0.008594
#
#                                               Mean of the integrated profile  \
# id                                                                  0.012082
# Mean of the integrated profile                                      1.000000
# Standard deviation of the integrated profile                        0.552478
# ...

# %%
data.isnull().sum()
# Out:
# id                                              0
# Mean of the integrated profile                  0
# Standard deviation of the integrated profile    0
# Excess kurtosis of the integrated profile       0
# Skewness of the integrated profile              0
# Mean of the DM-SNR curve                        0
# Standard deviation of the DM-SNR curve          0
# Excess kurtosis of the DM-SNR curve             0
# Skewness of the DM-SNR curve                    0
# target_class                                    0
# dtype: int64

# %%
data.shape
# Out:
# (14318, 10)

# %%
print("Total number of target_class: {}".format(data.shape[0]))
print("Number of 0: {}".format(data[data.target_class == 0].shape[0]))
print("Number of 1: {}".format(data[data.target_class == 1].shape[0]))
# Out:
# Total number of target_class: 14318
# Number of 0: 13003
# Number of 1: 1315

# %%
data.shape
# Out:
# (14318, 10)

# %% [markdown]
# ### Splitting into X and y

# %%
X=data.iloc[:, :-1]
X.head()
# Out:
#       id  Mean of the integrated profile  \
# 0  16330                      138.835938
# 1   5999                      130.296875
# 2  10228                      127.328125
# 3   2980                      102.453125
# 4   2472                      104.921875
#
#    Standard deviation of the integrated profile  \
# 0                                     45.453922
# 1                                     51.969546
# 2                                     55.471714
# 3                                     44.412987
# 4                                     41.629431
#
#    Excess kurtosis of the integrated profile  \
# 0                                  -0.096961
# 1                                  -0.005585
# 2                                   0.090976
# 3                                   0.652927
# 4                                   0.189677
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                            0.086516                  3.082776
# ...

# %%
y=data.iloc[:,-1]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 14313    0
# 14314    0
# 14315    0
# 14316    0
# 14317    0
# Name: target_class, Length: 14318, dtype: int64

# %% [markdown]
# ### Scaling the data

# %%
# Scale the data to be between -1 and 1
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %% [markdown]
# ### Splitting this data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (11454, 9) (2864, 9) (11454,) (2864,)

# %% [markdown]
# ### Cross validation

# %%
#cross valdn
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
svc=SVC(kernel='rbf')
scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy')
print(scores)
# Out:
# [0.97835196 0.98114525 0.98463687 0.97765363 0.98044693 0.98324022
#  0.97765363 0.97276536 0.98322851 0.9769392 ]

# %% [markdown]
# ### Accuracy

# %%
from sklearn import metrics
svc=SVC() #Default hyperparameters
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9797486033519553

# %% [markdown]
# ### Loading test data

# %%
test_data  = pd.read_csv("C:\\Users\\samee\\Downloads\\test.csv")
test_data.head()
# Out:
#    id  Mean of the integrated profile  \
# 0  15                      130.960938
# 1  28                       23.703125
# 2  30                      113.882812
# 3  35                      101.882812
# 4  48                       96.335938
#
#    Standard deviation of the integrated profile  \
# 0                                     51.285872
# 1                                     41.677774
# 2                                     45.562907
# 3                                     44.301633
# 4                                     43.957060
#
#    Excess kurtosis of the integrated profile  \
# 0                                   0.072242
# 1                                   4.112599
# 2                                   0.064720
# 3                                   0.584880
# 4                                   0.302221
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                           -0.584550                  1.940635
# ...

# %%
test_data.corr()
# Out:
#                                                     id  \
# id                                            1.000000
# Mean of the integrated profile                0.000770
# Standard deviation of the integrated profile -0.020027
# Excess kurtosis of the integrated profile     0.007923
# Skewness of the integrated profile            0.011200
# Mean of the DM-SNR curve                     -0.016730
# Standard deviation of the DM-SNR curve       -0.031661
# Excess kurtosis of the DM-SNR curve           0.009459
# Skewness of the DM-SNR curve                 -0.004250
#
#                                               Mean of the integrated profile  \
# id                                                                  0.000770
# Mean of the integrated profile                                      1.000000
# Standard deviation of the integrated profile                        0.525318
# Excess kurtosis of the integrated profile                          -0.875686
# ...

# %%
test_data.isnull().sum()
# Out:
# id                                              0
# Mean of the integrated profile                  0
# Standard deviation of the integrated profile    0
# Excess kurtosis of the integrated profile       0
# Skewness of the integrated profile              0
# Mean of the DM-SNR curve                        0
# Standard deviation of the DM-SNR curve          0
# Excess kurtosis of the DM-SNR curve             0
# Skewness of the DM-SNR curve                    0
# dtype: int64

# %%
test_data.shape
# Out:
# (3580, 9)

# %%
from sklearn import preprocessing
d=preprocessing.scale(test_data)
test_data1=pd.DataFrame(d,columns=test_data.columns)

# %% [markdown]
# ### Predictions

# %%
pred=svc.predict(test_data1)

# %%
pred
# Out:
# array([0, 1, 0, ..., 1, 0, 0], dtype=int64)

# %% [markdown]
# ### Creating csv predictions file

# %%
df=pd.DataFrame(zip(test_data['id'],pred), columns = ['id', 'target_class'])
df.to_csv('2kaggle_try.csv', index = False)
